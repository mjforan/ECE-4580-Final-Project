# %%
from google.colab import drive
drive.mount('/content/drive')
base_path = "/content/drive/Shareddrives/ECE 4580 Final Project/Colab/"
# Out:
# Mounted at /content/drive

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.regularizers import l2
import pandas as pd
import tensorflow as tf
import numpy as np
import os
import cv2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint, EarlyStopping
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
'''
This function will instantiate a Keras sequential model and incrementally add layers with the correct parameters

This architecture was designed by Furkan Kinli, Ph.D. His methodology is described here: https://medium.com/@birdortyedi_23820/deep-learning-lab-episode-3-fer2013-c38f2e052280

:param width: the width of the input images
:param height: the height of the input images
:param num_features: the dimensionality of each layers output. This changes the number of convolutional filters that pass over the image
:param num_labels: the size of the output. In this case, it is the number of emotions that can be classified
'''
def create_model(width, height, num_features, num_labels):
    #instantiate a Keras Sequential object to construct the model
    model = Sequential()

    # use a series of convolutional layers to downsample the 2d input
    # followed by batchnorm for normalization 
    # pooling to reduce the dimensionality
    # dropout to randomly remove weights to reduce overfitting 
    # relu (Rectified Linear Unit) is standard in most networks to add in non-linearity
    model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))
    model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.5))

    model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.5))

    model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.5))

    model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Dropout(0.5))

    # flatten will reshape the 2d output of the convolutional layers to a 1d vector
    model.add(Flatten())

    # follow convolutional layers with a few simple fully connected (dense) layers
    # still use dropout to reduce overfitting
    model.add(Dense(2*2*2*num_features, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(2*2*num_features, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(2*num_features, activation='relu'))
    model.add(Dropout(0.5))

    # the final softmax layer will specify the output size
    # softmax activation is used for categorical classification
    model.add(Dense(num_labels, activation='softmax'))

    return model

# %%
'''
Read in the csv data from the fer2013 dataset and load it into a pandas dataframe
'''
EMOTIONS = {
    0:"angry",
    1:"disgust",
    2:"fear",
    3:"happy",
    4:"sad",
    5:"surprise",
    6:"neutral"
}

train_dir = base_path+"data/train.csv"

df = pd.read_csv(train_dir)

# convert pixel strings into 2d numpy arrays
#faces = df['pixels'].apply(string_to_image)

pixels = df['pixels'].tolist()
faces = []
for sequence in pixels:
    face = [int(pixel) for pixel in sequence.split()]
    face = np.asarray(face).reshape(48, 48)
    face = cv2.resize(face.astype('uint8'), (48, 48))
    faces.append(face.astype('float32'))


#expand the channel dimension of each image
faces = np.asarray(faces)
faces = np.expand_dims(faces, -1)

#convert labels to categorical matrix
emotions = pd.get_dummies(df['emotion']).values

# get train-test split
x_train, x_test, y_train, y_test = train_test_split(faces, emotions, test_size=0.1, random_state=42)

# split training once more into validation
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=69)

# %%
'''
Train the model
'''
num_features = 64
num_labels = 7
batch_size = 64
epochs = 100
width, height = 48, 48
model = create_model(width=width, height=height, num_features=num_features, num_labels=num_labels)

model.summary()

optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
model.compile(loss=categorical_crossentropy, optimizer=optimizer, metrics=['accuracy'])

# call custom function to get a list of callback objects
callbacks = []
# add callbacks
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3, verbose=True)
callbacks.append(lr_reducer)

# save logs in separate directories
tb_logdir= os.path.join(os.getcwd(), 'training_logs')
i = 0 
while os.path.exists(os.path.join(tb_logdir, str(i))):
    i += 1
tb_logdir = os.path.join(tb_logdir, str(i))
os.makedirs(tb_logdir)

tb = TensorBoard(log_dir=tb_logdir)
callbacks.append(tb)

checkpoint_fpath = os.path.join(tb_logdir, "checkpoint_weights.{epoch:02d}")
checkpointer = ModelCheckpoint(checkpoint_fpath, monitor='val_loss', verbose=True, save_best_only=True)
callbacks.append(checkpointer)

# train the model
model.fit(np.array(x_train), np.array(y_train), 
    batch_size=batch_size,
    epochs=epochs,
    verbose=True,
    validation_data=(x_test, y_test), 
    shuffle=True,
    callbacks=callbacks
)

scores = model.evaluate(np.array(x_test), np.array(y_test), batch_size=batch_size)
print(f"Loss: {scores[0]}")
print(f"Accuracy: {scores[1]}")

model.save(base_path+"vt-moji-0")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 5,905,863
# Trainable params: 5,902,151
# Non-trainable params: 3,712
# _________________________________________________________________
# Epoch 1/100
#   1/364 [..............................] - ETA: 0s - loss: 6.0052 - accuracy: 0.1250WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/364 [..............................] - ETA: 19s - loss: 5.1127 - accuracy: 0.1719WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0250s vs `on_train_batch_end` time: 0.0853s). Check your callbacks.
# 364/364 [==============================] - ETA: 0s - loss: 2.0286 - accuracy: 0.2108
# Epoch 00001: val_loss improved from inf to 1.81542, saving model to /content/training_logs/0/checkpoint_weights.01
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.01/assets
# 364/364 [==============================] - 21s 57ms/step - loss: 2.0286 - accuracy: 0.2108 - val_loss: 1.8154 - val_accuracy: 0.2577
# Epoch 2/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.8436 - accuracy: 0.2434
# Epoch 00002: val_loss did not improve from 1.81542
# 364/364 [==============================] - 16s 45ms/step - loss: 1.8436 - accuracy: 0.2434 - val_loss: 1.8183 - val_accuracy: 0.2571
# Epoch 3/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.8203 - accuracy: 0.2535
# Epoch 00003: val_loss improved from 1.81542 to 1.79334, saving model to /content/training_logs/0/checkpoint_weights.03
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.03/assets
# 364/364 [==============================] - 20s 55ms/step - loss: 1.8203 - accuracy: 0.2535 - val_loss: 1.7933 - val_accuracy: 0.2571
# Epoch 4/100
# 364/364 [==============================] - ETA: 0s - loss: 1.7671 - accuracy: 0.2808
# Epoch 00004: val_loss did not improve from 1.79334
# 364/364 [==============================] - 16s 45ms/step - loss: 1.7671 - accuracy: 0.2808 - val_loss: 1.8777 - val_accuracy: 0.2571
# Epoch 5/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.6995 - accuracy: 0.3146
# Epoch 00005: val_loss improved from 1.79334 to 1.70640, saving model to /content/training_logs/0/checkpoint_weights.05
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.05/assets
# 364/364 [==============================] - 21s 58ms/step - loss: 1.6996 - accuracy: 0.3146 - val_loss: 1.7064 - val_accuracy: 0.3044
# Epoch 6/100
# 364/364 [==============================] - ETA: 0s - loss: 1.6155 - accuracy: 0.3599
# Epoch 00006: val_loss did not improve from 1.70640
# 364/364 [==============================] - 17s 47ms/step - loss: 1.6155 - accuracy: 0.3599 - val_loss: 1.7158 - val_accuracy: 0.3309
# Epoch 7/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.5554 - accuracy: 0.3915
# Epoch 00007: val_loss improved from 1.70640 to 1.47794, saving model to /content/training_logs/0/checkpoint_weights.07
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.07/assets
# 364/364 [==============================] - 21s 57ms/step - loss: 1.5551 - accuracy: 0.3915 - val_loss: 1.4779 - val_accuracy: 0.3953
# Epoch 8/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.4967 - accuracy: 0.4169
# Epoch 00008: val_loss improved from 1.47794 to 1.38987, saving model to /content/training_logs/0/checkpoint_weights.08
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.08/assets
# 364/364 [==============================] - 20s 56ms/step - loss: 1.4964 - accuracy: 0.4170 - val_loss: 1.3899 - val_accuracy: 0.4518
# Epoch 9/100
# 364/364 [==============================] - ETA: 0s - loss: 1.4517 - accuracy: 0.4387
# Epoch 00009: val_loss improved from 1.38987 to 1.36723, saving model to /content/training_logs/0/checkpoint_weights.09
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.09/assets
# 364/364 [==============================] - 21s 57ms/step - loss: 1.4517 - accuracy: 0.4387 - val_loss: 1.3672 - val_accuracy: 0.4688
# Epoch 10/100
# 364/364 [==============================] - ETA: 0s - loss: 1.4118 - accuracy: 0.4565
# Epoch 00010: val_loss improved from 1.36723 to 1.29113, saving model to /content/training_logs/0/checkpoint_weights.10
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.10/assets
# 364/364 [==============================] - 21s 57ms/step - loss: 1.4118 - accuracy: 0.4565 - val_loss: 1.2911 - val_accuracy: 0.4977
# Epoch 11/100
# 364/364 [==============================] - ETA: 0s - loss: 1.3785 - accuracy: 0.4752
# Epoch 00011: val_loss did not improve from 1.29113
# 364/364 [==============================] - 17s 46ms/step - loss: 1.3785 - accuracy: 0.4752 - val_loss: 1.5397 - val_accuracy: 0.3828
# Epoch 12/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.3514 - accuracy: 0.4864
# Epoch 00012: val_loss did not improve from 1.29113
# 364/364 [==============================] - 17s 46ms/step - loss: 1.3512 - accuracy: 0.4866 - val_loss: 1.2925 - val_accuracy: 0.5165
# Epoch 13/100
# 364/364 [==============================] - ETA: 0s - loss: 1.3130 - accuracy: 0.5010
# Epoch 00013: val_loss improved from 1.29113 to 1.27069, saving model to /content/training_logs/0/checkpoint_weights.13
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.13/assets
# 364/364 [==============================] - 20s 56ms/step - loss: 1.3130 - accuracy: 0.5010 - val_loss: 1.2707 - val_accuracy: 0.5336
# Epoch 14/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.2875 - accuracy: 0.5203
# Epoch 00014: val_loss improved from 1.27069 to 1.23085, saving model to /content/training_logs/0/checkpoint_weights.14
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.14/assets
# 364/364 [==============================] - 20s 56ms/step - loss: 1.2876 - accuracy: 0.5203 - val_loss: 1.2309 - val_accuracy: 0.5193
# Epoch 15/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.2618 - accuracy: 0.5223
# Epoch 00015: val_loss did not improve from 1.23085
# 364/364 [==============================] - 17s 46ms/step - loss: 1.2624 - accuracy: 0.5221 - val_loss: 1.3411 - val_accuracy: 0.4838
# Epoch 16/100
# 364/364 [==============================] - ETA: 0s - loss: 1.2429 - accuracy: 0.5316
# Epoch 00016: val_loss improved from 1.23085 to 1.19491, saving model to /content/training_logs/0/checkpoint_weights.16
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.16/assets
# 364/364 [==============================] - 20s 56ms/step - loss: 1.2429 - accuracy: 0.5316 - val_loss: 1.1949 - val_accuracy: 0.5507
# Epoch 17/100
# 364/364 [==============================] - ETA: 0s - loss: 1.2232 - accuracy: 0.5465
# Epoch 00017: val_loss did not improve from 1.19491
# 364/364 [==============================] - 17s 46ms/step - loss: 1.2232 - accuracy: 0.5465 - val_loss: 1.2087 - val_accuracy: 0.5479
# Epoch 18/100
# 364/364 [==============================] - ETA: 0s - loss: 1.1900 - accuracy: 0.5553
# Epoch 00018: val_loss improved from 1.19491 to 1.16898, saving model to /content/training_logs/0/checkpoint_weights.18
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.18/assets
# 364/364 [==============================] - 20s 55ms/step - loss: 1.1900 - accuracy: 0.5553 - val_loss: 1.1690 - val_accuracy: 0.5674
# Epoch 19/100
# 364/364 [==============================] - ETA: 0s - loss: 1.1778 - accuracy: 0.5650
# Epoch 00019: val_loss did not improve from 1.16898
# 364/364 [==============================] - 17s 46ms/step - loss: 1.1778 - accuracy: 0.5650 - val_loss: 1.1901 - val_accuracy: 0.5608
# Epoch 20/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.1650 - accuracy: 0.5752
# Epoch 00020: val_loss did not improve from 1.16898
# 364/364 [==============================] - 17s 46ms/step - loss: 1.1650 - accuracy: 0.5753 - val_loss: 1.2059 - val_accuracy: 0.5559
# Epoch 21/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.1298 - accuracy: 0.5873
# Epoch 00021: val_loss improved from 1.16898 to 1.14361, saving model to /content/training_logs/0/checkpoint_weights.21
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.21/assets
# 364/364 [==============================] - 21s 57ms/step - loss: 1.1297 - accuracy: 0.5873 - val_loss: 1.1436 - val_accuracy: 0.5761
# Epoch 22/100
# 364/364 [==============================] - ETA: 0s - loss: 1.1177 - accuracy: 0.5947
# Epoch 00022: val_loss improved from 1.14361 to 1.11959, saving model to /content/training_logs/0/checkpoint_weights.22
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.22/assets
# 364/364 [==============================] - 20s 56ms/step - loss: 1.1177 - accuracy: 0.5947 - val_loss: 1.1196 - val_accuracy: 0.5956
# Epoch 23/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.1023 - accuracy: 0.6015
# Epoch 00023: val_loss did not improve from 1.11959
# 364/364 [==============================] - 17s 46ms/step - loss: 1.1023 - accuracy: 0.6015 - val_loss: 1.1216 - val_accuracy: 0.5883
# Epoch 24/100
# 364/364 [==============================] - ETA: 0s - loss: 1.0745 - accuracy: 0.6106
# Epoch 00024: val_loss did not improve from 1.11959
# 364/364 [==============================] - 17s 46ms/step - loss: 1.0745 - accuracy: 0.6106 - val_loss: 1.2118 - val_accuracy: 0.5618
# Epoch 25/100
# 363/364 [============================>.] - ETA: 0s - loss: 1.0543 - accuracy: 0.6165
# Epoch 00025: val_loss improved from 1.11959 to 1.11668, saving model to /content/training_logs/0/checkpoint_weights.25
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.25/assets
# 364/364 [==============================] - 21s 56ms/step - loss: 1.0546 - accuracy: 0.6164 - val_loss: 1.1167 - val_accuracy: 0.6068
# Epoch 26/100
# 364/364 [==============================] - ETA: 0s - loss: 1.0402 - accuracy: 0.6232
# Epoch 00026: val_loss did not improve from 1.11668
# 364/364 [==============================] - 17s 46ms/step - loss: 1.0402 - accuracy: 0.6232 - val_loss: 1.1522 - val_accuracy: 0.5772
# Epoch 27/100
# 364/364 [==============================] - ETA: 0s - loss: 1.0058 - accuracy: 0.6351
# Epoch 00027: val_loss improved from 1.11668 to 1.08524, saving model to /content/training_logs/0/checkpoint_weights.27
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.27/assets
# 364/364 [==============================] - 20s 56ms/step - loss: 1.0058 - accuracy: 0.6351 - val_loss: 1.0852 - val_accuracy: 0.6050
# Epoch 28/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.9914 - accuracy: 0.6418
# Epoch 00028: val_loss did not improve from 1.08524
# 364/364 [==============================] - 17s 46ms/step - loss: 0.9914 - accuracy: 0.6418 - val_loss: 1.1013 - val_accuracy: 0.6061
# Epoch 29/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.9711 - accuracy: 0.6496
# Epoch 00029: val_loss did not improve from 1.08524
# 364/364 [==============================] - 17s 46ms/step - loss: 0.9712 - accuracy: 0.6495 - val_loss: 1.1311 - val_accuracy: 0.6043
# Epoch 30/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.9500 - accuracy: 0.6559
# Epoch 00030: val_loss improved from 1.08524 to 1.07718, saving model to /content/training_logs/0/checkpoint_weights.30
# INFO:tensorflow:Assets written to: /content/training_logs/0/checkpoint_weights.30/assets
# 364/364 [==============================] - 20s 56ms/step - loss: 0.9501 - accuracy: 0.6559 - val_loss: 1.0772 - val_accuracy: 0.6137
# Epoch 31/100
# 364/364 [==============================] - ETA: 0s - loss: 0.9443 - accuracy: 0.6593
# Epoch 00031: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.9443 - accuracy: 0.6593 - val_loss: 1.1264 - val_accuracy: 0.6207
# Epoch 32/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.9265 - accuracy: 0.6650
# Epoch 00032: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.9263 - accuracy: 0.6651 - val_loss: 1.1473 - val_accuracy: 0.6047
# Epoch 33/100
# 364/364 [==============================] - ETA: 0s - loss: 0.9100 - accuracy: 0.6742
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 00033: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.9100 - accuracy: 0.6742 - val_loss: 1.1822 - val_accuracy: 0.6019
# Epoch 34/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.8744 - accuracy: 0.6857
# Epoch 00034: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.8743 - accuracy: 0.6857 - val_loss: 1.1119 - val_accuracy: 0.6193
# Epoch 35/100
# 364/364 [==============================] - ETA: 0s - loss: 0.8534 - accuracy: 0.6935
# Epoch 00035: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.8534 - accuracy: 0.6935 - val_loss: 1.0790 - val_accuracy: 0.6085
# Epoch 36/100
# 364/364 [==============================] - ETA: 0s - loss: 0.8344 - accuracy: 0.7015
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 00036: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.8344 - accuracy: 0.7015 - val_loss: 1.1018 - val_accuracy: 0.6210
# Epoch 37/100
# 364/364 [==============================] - ETA: 0s - loss: 0.8045 - accuracy: 0.7073
# Epoch 00037: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.8045 - accuracy: 0.7073 - val_loss: 1.1095 - val_accuracy: 0.6263
# Epoch 38/100
# 364/364 [==============================] - ETA: 0s - loss: 0.7868 - accuracy: 0.7181
# Epoch 00038: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.7868 - accuracy: 0.7181 - val_loss: 1.1407 - val_accuracy: 0.6186
# Epoch 39/100
# 364/364 [==============================] - ETA: 0s - loss: 0.7635 - accuracy: 0.7287
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 00039: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.7635 - accuracy: 0.7287 - val_loss: 1.1455 - val_accuracy: 0.6270
# Epoch 40/100
# 364/364 [==============================] - ETA: 0s - loss: 0.7379 - accuracy: 0.7317
# Epoch 00040: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.7379 - accuracy: 0.7317 - val_loss: 1.1431 - val_accuracy: 0.6249
# Epoch 41/100
# 364/364 [==============================] - ETA: 0s - loss: 0.7107 - accuracy: 0.7451
# Epoch 00041: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.7107 - accuracy: 0.7451 - val_loss: 1.1269 - val_accuracy: 0.6378
# Epoch 42/100
# 364/364 [==============================] - ETA: 0s - loss: 0.6980 - accuracy: 0.7515
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 00042: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.6980 - accuracy: 0.7515 - val_loss: 1.1292 - val_accuracy: 0.6263
# Epoch 43/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.6768 - accuracy: 0.7568
# Epoch 00043: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.6770 - accuracy: 0.7569 - val_loss: 1.2459 - val_accuracy: 0.6245
# Epoch 44/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.6572 - accuracy: 0.7675
# Epoch 00044: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.6575 - accuracy: 0.7674 - val_loss: 1.1569 - val_accuracy: 0.6437
# Epoch 45/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.6445 - accuracy: 0.7724
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 00045: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.6445 - accuracy: 0.7724 - val_loss: 1.1726 - val_accuracy: 0.6430
# Epoch 46/100
# 364/364 [==============================] - ETA: 0s - loss: 0.6167 - accuracy: 0.7827
# Epoch 00046: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.6167 - accuracy: 0.7827 - val_loss: 1.1911 - val_accuracy: 0.6440
# Epoch 47/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.5983 - accuracy: 0.7866
# Epoch 00047: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.5983 - accuracy: 0.7866 - val_loss: 1.1992 - val_accuracy: 0.6458
# Epoch 48/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.5791 - accuracy: 0.7961
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0005314410547725857.
#
# Epoch 00048: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.5793 - accuracy: 0.7959 - val_loss: 1.2395 - val_accuracy: 0.6203
# Epoch 49/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.5619 - accuracy: 0.8027
# Epoch 00049: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.5620 - accuracy: 0.8027 - val_loss: 1.2563 - val_accuracy: 0.6392
# Epoch 50/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.5515 - accuracy: 0.8055
# Epoch 00050: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 45ms/step - loss: 0.5515 - accuracy: 0.8055 - val_loss: 1.1985 - val_accuracy: 0.6461
# Epoch 51/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.5320 - accuracy: 0.8151
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00047829695977270604.
#
# Epoch 00051: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.5322 - accuracy: 0.8151 - val_loss: 1.2309 - val_accuracy: 0.6419
# Epoch 52/100
# 364/364 [==============================] - ETA: 0s - loss: 0.5181 - accuracy: 0.8170
# Epoch 00052: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 45ms/step - loss: 0.5181 - accuracy: 0.8170 - val_loss: 1.2611 - val_accuracy: 0.6381
# Epoch 53/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.5030 - accuracy: 0.8237
# Epoch 00053: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.5032 - accuracy: 0.8237 - val_loss: 1.2764 - val_accuracy: 0.6336
# Epoch 54/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.4892 - accuracy: 0.8290
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.0004304672533180565.
#
# Epoch 00054: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.4893 - accuracy: 0.8289 - val_loss: 1.3635 - val_accuracy: 0.6329
# Epoch 55/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.4757 - accuracy: 0.8353
# Epoch 00055: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.4757 - accuracy: 0.8354 - val_loss: 1.2921 - val_accuracy: 0.6284
# Epoch 56/100
# 364/364 [==============================] - ETA: 0s - loss: 0.4629 - accuracy: 0.8403
# Epoch 00056: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.4629 - accuracy: 0.8403 - val_loss: 1.3593 - val_accuracy: 0.6374
# Epoch 57/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.4467 - accuracy: 0.8432
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.00038742052274756136.
#
# Epoch 00057: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.4465 - accuracy: 0.8433 - val_loss: 1.3725 - val_accuracy: 0.6332
# Epoch 58/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.4352 - accuracy: 0.8489
# Epoch 00058: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.4354 - accuracy: 0.8488 - val_loss: 1.3816 - val_accuracy: 0.6357
# Epoch 59/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.4252 - accuracy: 0.8525
# Epoch 00059: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.4253 - accuracy: 0.8525 - val_loss: 1.3429 - val_accuracy: 0.6290
# Epoch 60/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.4252 - accuracy: 0.8546
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.0003486784757114947.
#
# Epoch 00060: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.4252 - accuracy: 0.8545 - val_loss: 1.3641 - val_accuracy: 0.6412
# Epoch 61/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3956 - accuracy: 0.8641
# Epoch 00061: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3961 - accuracy: 0.8640 - val_loss: 1.3939 - val_accuracy: 0.6371
# Epoch 62/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3978 - accuracy: 0.8646
# Epoch 00062: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 45ms/step - loss: 0.3980 - accuracy: 0.8646 - val_loss: 1.3760 - val_accuracy: 0.6364
# Epoch 63/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3796 - accuracy: 0.8650
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.00031381062290165574.
#
# Epoch 00063: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3798 - accuracy: 0.8650 - val_loss: 1.4278 - val_accuracy: 0.6357
# Epoch 64/100
# 364/364 [==============================] - ETA: 0s - loss: 0.3692 - accuracy: 0.8753
# Epoch 00064: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3692 - accuracy: 0.8753 - val_loss: 1.4901 - val_accuracy: 0.6444
# Epoch 65/100
# 364/364 [==============================] - ETA: 0s - loss: 0.3561 - accuracy: 0.8780
# Epoch 00065: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3561 - accuracy: 0.8780 - val_loss: 1.4783 - val_accuracy: 0.6360
# Epoch 66/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3622 - accuracy: 0.8774
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.0002824295632308349.
#
# Epoch 00066: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3621 - accuracy: 0.8774 - val_loss: 1.4368 - val_accuracy: 0.6409
# Epoch 67/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3506 - accuracy: 0.8817
# Epoch 00067: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3504 - accuracy: 0.8817 - val_loss: 1.4280 - val_accuracy: 0.6412
# Epoch 68/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3241 - accuracy: 0.8890
# Epoch 00068: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3240 - accuracy: 0.8891 - val_loss: 1.5022 - val_accuracy: 0.6458
# Epoch 69/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3292 - accuracy: 0.8895
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.00025418660952709616.
#
# Epoch 00069: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3290 - accuracy: 0.8896 - val_loss: 1.5313 - val_accuracy: 0.6465
# Epoch 70/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3189 - accuracy: 0.8913
# Epoch 00070: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3189 - accuracy: 0.8913 - val_loss: 1.5630 - val_accuracy: 0.6444
# Epoch 71/100
# 364/364 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.8923
# Epoch 00071: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3187 - accuracy: 0.8923 - val_loss: 1.5477 - val_accuracy: 0.6489
# Epoch 72/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.3050 - accuracy: 0.8986
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.00022876793809700757.
#
# Epoch 00072: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.3050 - accuracy: 0.8987 - val_loss: 1.5898 - val_accuracy: 0.6458
# Epoch 73/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.9023
# Epoch 00073: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2955 - accuracy: 0.9023 - val_loss: 1.5855 - val_accuracy: 0.6461
# Epoch 74/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.2877 - accuracy: 0.9050
# Epoch 00074: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2875 - accuracy: 0.9050 - val_loss: 1.5223 - val_accuracy: 0.6482
# Epoch 75/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.2923 - accuracy: 0.9030
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.00020589114428730683.
#
# Epoch 00075: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2921 - accuracy: 0.9030 - val_loss: 1.4969 - val_accuracy: 0.6437
# Epoch 76/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.9070
# Epoch 00076: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2809 - accuracy: 0.9070 - val_loss: 1.5364 - val_accuracy: 0.6541
# Epoch 77/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.2724 - accuracy: 0.9084
# Epoch 00077: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2727 - accuracy: 0.9083 - val_loss: 1.5740 - val_accuracy: 0.6465
# Epoch 78/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.2728 - accuracy: 0.9092
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.00018530203378759326.
#
# Epoch 00078: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2731 - accuracy: 0.9091 - val_loss: 1.5865 - val_accuracy: 0.6482
# Epoch 79/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.2674 - accuracy: 0.9108
# Epoch 00079: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2673 - accuracy: 0.9108 - val_loss: 1.5529 - val_accuracy: 0.6499
# Epoch 80/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2645 - accuracy: 0.9108
# Epoch 00080: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2645 - accuracy: 0.9108 - val_loss: 1.5720 - val_accuracy: 0.6517
# Epoch 81/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.9120
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 0.00016677183302817866.
#
# Epoch 00081: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2625 - accuracy: 0.9120 - val_loss: 1.5574 - val_accuracy: 0.6402
# Epoch 82/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9155
# Epoch 00082: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2494 - accuracy: 0.9155 - val_loss: 1.6702 - val_accuracy: 0.6499
# Epoch 83/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.9189
# Epoch 00083: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2475 - accuracy: 0.9189 - val_loss: 1.6763 - val_accuracy: 0.6475
# Epoch 84/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9161
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.00015009464841568844.
#
# Epoch 00084: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2492 - accuracy: 0.9161 - val_loss: 1.6888 - val_accuracy: 0.6440
# Epoch 85/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2376 - accuracy: 0.9199
# Epoch 00085: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2376 - accuracy: 0.9199 - val_loss: 1.7137 - val_accuracy: 0.6447
# Epoch 86/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.2336 - accuracy: 0.9239
# Epoch 00086: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2335 - accuracy: 0.9240 - val_loss: 1.6713 - val_accuracy: 0.6451
# Epoch 87/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9234
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 0.0001350851875031367.
#
# Epoch 00087: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2302 - accuracy: 0.9234 - val_loss: 1.6845 - val_accuracy: 0.6472
# Epoch 88/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.9265
# Epoch 00088: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2249 - accuracy: 0.9265 - val_loss: 1.7260 - val_accuracy: 0.6430
# Epoch 89/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9249
# Epoch 00089: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2272 - accuracy: 0.9249 - val_loss: 1.7152 - val_accuracy: 0.6520
# Epoch 90/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9275
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 0.00012157666351413355.
#
# Epoch 00090: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2227 - accuracy: 0.9275 - val_loss: 1.6746 - val_accuracy: 0.6423
# Epoch 91/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9285
# Epoch 00091: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2217 - accuracy: 0.9285 - val_loss: 1.7108 - val_accuracy: 0.6465
# Epoch 92/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9305
# Epoch 00092: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2079 - accuracy: 0.9305 - val_loss: 1.7496 - val_accuracy: 0.6489
# Epoch 93/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2116 - accuracy: 0.9309
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 0.00010941899454337544.
#
# Epoch 00093: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2116 - accuracy: 0.9309 - val_loss: 1.7289 - val_accuracy: 0.6398
# Epoch 94/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.2108 - accuracy: 0.9317
# Epoch 00094: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2112 - accuracy: 0.9315 - val_loss: 1.7142 - val_accuracy: 0.6465
# Epoch 95/100
# 364/364 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9336
# Epoch 00095: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.1997 - accuracy: 0.9336 - val_loss: 1.7920 - val_accuracy: 0.6479
# Epoch 96/100
# 364/364 [==============================] - ETA: 0s - loss: 0.1975 - accuracy: 0.9359
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 9.847709443420172e-05.
#
# Epoch 00096: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.1975 - accuracy: 0.9359 - val_loss: 1.8009 - val_accuracy: 0.6465
# Epoch 97/100
# 364/364 [==============================] - ETA: 0s - loss: 0.2024 - accuracy: 0.9361
# Epoch 00097: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.2024 - accuracy: 0.9361 - val_loss: 1.7998 - val_accuracy: 0.6506
# Epoch 98/100
# 364/364 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9368
# Epoch 00098: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.1889 - accuracy: 0.9368 - val_loss: 1.8818 - val_accuracy: 0.6486
# Epoch 99/100
# 364/364 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9353
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 8.862938630045391e-05.
#
# Epoch 00099: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.1962 - accuracy: 0.9353 - val_loss: 1.7969 - val_accuracy: 0.6496
# Epoch 100/100
# 363/364 [============================>.] - ETA: 0s - loss: 0.1899 - accuracy: 0.9387
# Epoch 00100: val_loss did not improve from 1.07718
# 364/364 [==============================] - 17s 46ms/step - loss: 0.1899 - accuracy: 0.9387 - val_loss: 1.8410 - val_accuracy: 0.6486
# 45/45 [==============================] - 1s 13ms/step - loss: 1.8410 - accuracy: 0.6486
# Loss: 1.8410248756408691
# Accuracy: 0.6485545039176941
